# %%
import os
import sys
# /CHORD/audio_chords/notebooks/metrics.ipynb
sys.path.append(os.path.join('.', '..', '..', 'audio_chords'))

from utils import calc_wscr

# %%
metrics_file = '/storage/naumtsevalex/harmony/data/results/00_test_folder_nSplits_10/woNochord_withNegSamples/woNochord_withNegSamples_labeling.json'
calc_wscr(metrics_file=metrics_file, ignore_zero_chord=True)
# Out:
# acc=0.824590553060747, intersection=161.33224489799994, gt_labeling_duration=195.65133786599992
# score=0.824590553060747 mean_score=0.824590553060747
# acc=0.7555970149160299, intersection=112.8489795970001, gt_labeling_duration=149.350748308
# score=0.7555970149160299 mean_score=1.580187567976777
# acc=0.8064283134717184, intersection=103.70031745599996, gt_labeling_duration=128.59210883799997
# score=0.8064283134717184 mean_score=2.3866158814484955
# acc=0.8164464023324546, intersection=129.1029478459999, gt_labeling_duration=158.12789115999993
# score=0.8164464023324546 mean_score=3.20306228378095
# acc=0.6835125447976, intersection=88.56090703099999, gt_labeling_duration=129.56734694200003
# score=0.6835125447976 mean_score=3.88657482857855
# acc=0.7039602201887907, intersection=184.08780044899967, gt_labeling_duration=261.503129253
# score=0.7039602201887907 mean_score=4.590535048767341
# ...

# %%
calc_wscr(metrics_file=metrics_file, ignore_zero_chord=False)
