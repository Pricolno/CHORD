# %%
# %load_ext autoreload
# %autoreload 2

# %%
import datasets

# %%
chorales = datasets.chorales_dataset('bach_chorales/bach_choral_set_dataset.csv', use_double_harmony = False)
chorales.kfold_accuracy(mode='separately', kfolds=[0])
# Out:
# boundary segments: 142
# objects in dataset: 5523
# Counter({0: 702, 2: 694, 7: 680, 9: 610, 4: 590, 5: 473, 11: 413, 10: 316, 6: 285, 3: 146, 1: 99, 8: 46})
# Counter({1: 3521, 0: 1533})
# Counter({0: 469})
# Counter({1: 318, 0: 151})
# acc=0.8769230769230769, match_cnt=57, track_len=65
# acc=0.8148148148148148, match_cnt=66, track_len=81
# acc=0.8024691358024691, match_cnt=65, track_len=81
# acc=0.7948717948717948, match_cnt=62, track_len=78
# acc=0.8461538461538461, match_cnt=77, track_len=91
# acc=0.7638888888888888, match_cnt=55, track_len=72
# wscr=0.814498933901919
# Full Chord Metrics: {'AccE': 81.6631130063966, 'PS': 82.72138228941685, 'RS': 81.6631130063966, 'FS': 82.18884120171674}
# Root Only Metrics: {'AccE': 82.94243070362474, 'PS': 83.47639484978541, 'RS': 82.94243070362474, 'FS': 83.20855614973263}
# mean: 81.6631130063966

# %%
# acc=0.8461538461538461, match_cnt=55, track_len=65
# acc=0.7901234567901234, match_cnt=64, track_len=81
# acc=0.7901234567901234, match_cnt=64, track_len=81
# acc=0.782051282051282, match_cnt=61, track_len=78
# acc=0.8131868131868132, match_cnt=74, track_len=91
# acc=0.7361111111111112, match_cnt=53, track_len=72
# wscr=0.791044776119403

# acc=0.8769230769230769, match_cnt=57, track_len=65
# acc=0.8148148148148148, match_cnt=66, track_len=81
# acc=0.8024691358024691, match_cnt=65, track_len=81
# acc=0.7948717948717948, match_cnt=62, track_len=78
# acc=0.8461538461538461, match_cnt=77, track_len=91
# acc=0.7638888888888888, match_cnt=55, track_len=72
# wscr=0.814498933901919

# %%
25 / (25 + 6), 25 / (25 + 6)
# 20 / (20 + 8)
# Out:
# (0.8064516129032258, 0.8064516129032258)

# %%
#Full Chord Metrics: {'AccE': 81.6631130063966, 'PS': 82.72138228941685, 'RS': 81.6631130063966, 'FS': 82.18884120171674}
# Root Only Metrics: {'AccE': 82.94243070362474, 'PS': 83.47639484978541, 'RS': 82.94243070362474, 'FS': 83.20855614973263}



# weigth
# boundary segments: 142
# objects in dataset: 5523
# Full Chord Metrics: {'AccE': 84.00852878464818, 'PS': 86.63195977533874, 'RS': 84.0085287846482, 'FS': 84.82328513025165}
# Root Only Metrics: {'AccE': 91.25799573560768, 'PS': 91.7345440506492, 'RS': 91.25799573560768, 'FS': 91.33909452233812}
# mean: 84.00852878464818
# boundary segments: 142
# objects in dataset: 5523
# Counter({0: 702, 2: 694, 7: 680, 9: 610, 4: 590, 5: 473, 11: 413, 10: 316, 6: 285, 3: 146, 1: 99, 8: 46})
# Counter({1: 3521, 0: 1533})
# Counter({0: 469})
# Counter({1: 318, 0: 151})
# Full Chord Metrics: {'AccE': 81.6631130063966, 'PS': 84.24829835687618, 'RS': 81.66311300639661, 'FS': 82.41234419601703}
# Root Only Metrics: {'AccE': 82.94243070362474, 'PS': 83.90339719804659, 'RS': 82.94243070362474, 'FS': 83.18848358634683}
# mean: 81.6631130063966


# boundary segments: 142
# objects in dataset: 5523
# Counter({0: 702, 2: 694, 7: 680, 9: 610, 4: 590, 5: 473, 11: 413, 10: 316, 6: 285, 3: 146, 1: 99, 8: 46})
# Counter({1: 3521, 0: 1533})
# Counter({0: 469})
# Counter({1: 318, 0: 151})
# 0.8166311300639659
# Accuracy: 0.8166311300639659
# Full Chord Metrics: {'AccE': 0.8166311300639659, 'PS': 61.72106824925816, 'RS': 83.87096774193549, 'FS': 71.11111111111111}
# Root Only Metrics: {'AccE': 0.8294243070362474, 'PS': 62.727272727272734, 'RS': 84.8360655737705, 'FS': 72.12543554006969}
# mean: 0.8166311300639659

# %%
chorales = datasets.chorales_dataset('bach_chorales/bach_choral_set_dataset.csv', use_double_harmony = True)
chorales.kfold_accuracy(mode='separately', kfolds=[0])
# Out:
# boundary segments: 142
# objects in dataset: 5523
# Counter({0: 702, 2: 694, 7: 680, 9: 610, 4: 590, 5: 473, 11: 413, 10: 316, 6: 285, 3: 146, 1: 99, 8: 46})
# Counter({1: 3521, 0: 1533})
# Counter({0: 5054})
# Counter({1: 3474, 0: 1580})
# Counter({0: 702, 2: 694, 7: 680, 9: 610, 4: 590, 5: 473, 11: 413, 10: 316, 6: 285, 3: 146, 1: 99, 8: 46})
# Counter({1: 3521, 0: 1533})
# Counter({0: 469})
# Counter({1: 318, 0: 151})
# Counter({9: 97, 2: 96, 7: 72, 0: 55, 4: 41, 10: 31, 5: 24, 6: 20, 11: 17, 1: 11, 3: 5})
# Counter({1: 310, 0: 159})
# acc=0.8615384615384616, match_cnt=56, track_len=65
# acc=0.8395061728395061, match_cnt=68, track_len=81
# acc=0.8395061728395061, match_cnt=68, track_len=81
# acc=0.7948717948717948, match_cnt=62, track_len=78
# acc=0.9120879120879121, match_cnt=83, track_len=91
# acc=0.7777777777777778, match_cnt=56, track_len=72
# wscr=0.837953091684435
# ...

# %%
# acc=0.8615384615384616, match_cnt=56, track_len=65
# acc=0.8395061728395061, match_cnt=68, track_len=81
# acc=0.8395061728395061, match_cnt=68, track_len=81
# acc=0.7948717948717948, match_cnt=62, track_len=78
# acc=0.9120879120879121, match_cnt=83, track_len=91
# acc=0.7777777777777778, match_cnt=56, track_len=72
# wscr=0.837953091684435

# %%
# Full Chord Metrics: {'AccE': 84.00852878464818, 'PS': 85.09719222462203, 'RS': 84.00852878464818, 'FS': 84.54935622317596}
# Root Only Metrics: {'AccE': 91.25799573560768, 'PS': 91.25799573560768, 'RS': 91.25799573560768, 'FS': 91.25799573560768}


# w
# Full Chord Metrics: {'AccE': 84.00852878464818, 'PS': 86.63195977533874, 'RS': 84.0085287846482, 'FS': 84.82328513025165}
# Root Only Metrics: {'AccE': 91.25799573560768, 'PS': 91.7345440506492, 'RS': 91.25799573560768, 'FS': 91.33909452233812}
# mean: 84.00852878464818


# 2, 0: 55, 4: 41, 10: 31, 5: 24, 6: 20, 11: 17, 1: 11, 3: 5})
# Counter({1: 310, 0: 159})
# 0.8400852878464818
# Accuracy: 0.8400852878464818
# Full Chord Metrics: {'AccE': 0.8400852878464818, 'PS': 64.74164133738601, 'RS': 85.88709677419355, 'FS': 73.83015597920277}
# Root Only Metrics: {'AccE': 0.9125799573560768, 'PS': 77.18120805369128, 'RS': 94.26229508196722, 'FS': 84.8708487084871}
# mean: 0.8400852878464818

# %%
import pandas as pd 

df = pd.DataFrame({
     'a': [1, 2, 3],
     'b': [10, 20, 30]
})

# %%
# df['c'] =  df['a'].to_numpy()
# df['c'] =  df['a']
# arr = df['a'].to_numpy()[:, None].squeeze(axis=(1))
arr = df['a'].to_numpy()
arr.shape
# Out:
# (3,)

# %%
arr == df['a']
# Out:
# 0    True
# 1    True
# 2    True
# Name: a, dtype: bool
